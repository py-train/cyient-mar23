# %%
import pandas as pd

# %%
t = pd.read_csv('data/titanic.csv')
t
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# 1. a) How many males are there in this data?

# b) What is their %age?

# %%
# 2. What is the average age of the male survivors?

# %%
# 3. What are the unique passenger classes (pclass)?

# %%
# 4. The count of survivors by sex?

# %%
# 5. The count of survivors by sex and passenger class (pclass)

# Which pclass+gender appear to be having highest rates of survival?

# %%
# The counts above are ok, but a better picture would be presented 
# by using %ages for these numbers
# 6. Get the survivor percentages by sex and passenger class and 
#    again evaluate the survival rates

# %%
# 7. How many missing values do we have in this data

# %%
# 8. Drop the columns that have more than 60% missing values. How many NaN's remain?

# %%
# 9. Drop the rows that have less than 11 non-null values. How many NaN's remain?

# %%
# 10. Forward fill the remaining NaN's. How many NaN's remain?
